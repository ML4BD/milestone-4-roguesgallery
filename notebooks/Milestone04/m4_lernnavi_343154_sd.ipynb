# %% [markdown]
# # Data preprocessing Part II

# %%
# Import the tables of the data set as dataframes.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

DATA_DIR = './data' #You many change the directory

challenge_transactions = pd.read_csv('{}/challenge_transactions.csv.gz'.format(DATA_DIR))
documents = pd.read_csv('{}/documents.csv.gz'.format(DATA_DIR))
feedback = pd.read_csv('{}/feedback.csv.gz'.format(DATA_DIR))
learn_sessions_transactions = pd.read_csv('{}/learn_sessions_transactions.csv.gz'.format(DATA_DIR))
topic_trees = pd.read_csv('{}/topic_trees.csv.gz'.format(DATA_DIR))
topics_translated = pd.read_csv('{}/topics_translated.csv.gz'.format(DATA_DIR))
users = pd.read_csv('{}/users.csv.gz'.format(DATA_DIR))
events = pd.read_csv('{}/events.csv.gz'.format(DATA_DIR))
transactions = pd.read_csv('{}/transactions.csv.gz'.format(DATA_DIR))

# %%
def remove_users(events, transactions):
    tokens_event = set(events['transaction_token'].unique())
    print("{} tokens in events".format(len(tokens_event)))

    tokens_trans = set(transactions['transaction_token'].unique())
    print("{} tokens in transactions".format(len(tokens_trans)))

    missing_tokens = list(tokens_event - tokens_trans)
    missing_tokens.remove(np.nan)
    print("{} tokens in events but not in transactions".format(len(missing_tokens)))

    users_missing = list(events[events['transaction_token'].isin(missing_tokens)]['user_id'].unique())
    print("{} users in events but not in transactions".format(len(users_missing)))

    # Events without missing users. Equivalent to removing the missing tokens from events.
    len_events = len(events)
    events = events[~events['user_id'].isin(users_missing)]
    stat_events = (len_events - len(events))/len_events
    print("{}% of events eliminated".format(round(stat_events, 4)))

    return events, transactions
events, transactions = remove_users(events, transactions)
# Out:
# 637678 tokens in events
# 800018 tokens in transactions
# 37685 tokens in events but not in transactions
# 1304 users in events but not in transactions
# 0.0595% of events eliminated

# %% [markdown]
# Merging `learn_sessions_transactions` dataframe with `transactions` dataframe:

# %%
df = transactions.merge(learn_sessions_transactions, on = 'transaction_id')

# Printing the original shape of the data
print("Original shape of the data: ", df.shape)

df.head()
# Out:
# Original shape of the data:  (497263, 19)
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1          563378  b5978bb1-c34f-4157-9d1f-052b451edab5  387604.0
# 2         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 3          774545  64645a54-a4f3-4e7b-9f88-39205882d87d  387604.0
# 4          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  1aRVNzqunJs6eJCo9vZiy3             70675        NaN   NaN  1615192571101
# 2  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 3  1eWCmfpLnkQ96qFQp5XixR             95079        NaN   NaN  1630399544151
# 4  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
#
#     commit_time user_agent validation solution type  learn_session_id  \
# 0  1.645197e+12    unknown       SKIP      NaN  NaN            111059
# 1           NaN    unknown        NaN      NaN  NaN             14120
# 2           NaN    unknown        NaN      NaN  NaN             70380
# 3  1.630400e+12    unknown       SKIP      NaN  NaN             41166
# 4           NaN    unknown        NaN      NaN  NaN             44450
#
#    topic_id  max_num_tasks  is_closed  type_id  is_accepted
# 0      3250              5          0        1          NaN
# 1         3              5          1        1          1.0
# 2         3              5          1        2          NaN
# 3      3119              5          1        1          1.0
# 4      3119              5          1        2          NaN

# %% [markdown]
# ### Cleaning criteria 1
# Removing inactive students: those who did not perform any level check.
# Justification of the cleaning decision: our goal is to predict user's success in level checks based on their regularity in time. As a consequence, we are not interested in users who did not perform any level check.

# %% [markdown]
# Computing the number of checks performed by each user on the platform:

# %%
test_data = pd.DataFrame(df.groupby(['user_id', 'learn_session_id', 'type_id']).size())
test_data = test_data.reset_index()
test_data = test_data[test_data['type_id'] == 2]
test_data = test_data.rename(columns = {0 : "num_checks"}, errors = "raise")
test_data = test_data.drop(columns = ['type_id'])
test_data.head()
# Out:
#      user_id  learn_session_id  num_checks
# 6   387604.0             41319           4
# 8   387604.0             44450           1
# 9   387604.0             49468           1
# 10  387604.0             49471           1
# 11  387604.0             70380           1

# %% [markdown]
# Merging `df` with `test_data`:

# %%
df = df.merge(test_data, on = ['user_id', 'learn_session_id'])
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 1          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 2         1219464  b4c967f7-e82d-4a33-a251-a6cb82b339e2  387604.0
# 3         1219465  779bba4c-ff28-40df-8d30-2d4ea4a45cc5  387604.0
# 4          775986  4e3037c7-2597-4c44-808f-6f68963a6e1a  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 1  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 2  2lr1bK6ZNm36FHHh1xWNL1            108050        NaN   NaN  1639411227473
# 3  8PbBly3e13M739zExxyczD            108046        NaN   NaN  1639411238461
# 4  2P5i2sCDZuoarjyFyM6F1n             87512        NaN   NaN  1630481009625
#
#     commit_time user_agent validation solution type  learn_session_id  \
# 0           NaN    unknown        NaN      NaN  NaN             70380
# 1           NaN    unknown        NaN      NaN  NaN             44450
# 2  1.639411e+12    unknown       SKIP      NaN  NaN             84083
# 3           NaN    unknown        NaN      NaN  NaN             84083
# 4  1.630481e+12    unknown       SKIP      NaN  NaN             41319
#
#    topic_id  max_num_tasks  is_closed  type_id  is_accepted  num_checks
# 0         3              5          1        2          NaN           1
# 1      3119              5          1        2          NaN           1
# 2         3              5          1        2          NaN           2
# 3         3              5          1        2          NaN           2
# 4         3              5          1        2          NaN           4

# %% [markdown]
# Histogram of the number of *level checks* performed by the users of the platform:

# %%
num_checks = df['num_checks'].value_counts(dropna=False)
num_checks.plot(
   kind="hist",
   figsize=(8,5),
   title = "Histogram of Level Checks"
)
# Out:
# <AxesSubplot:title={'center':'Histogram of Level Checks'}, ylabel='Frequency'>

# %% [markdown]
# Removing users who have not performed any level check:

# %%
# Printing the shape of the framework before the cleaning process:
print("Shape before cleaning: ", df.shape)

# Cleaning the data...
df = df[df['num_checks'] > 0]

# Printing the shape of the framework after the cleaning process:
print("Shape after cleaning: ", df.shape)
df.head()
# Out:
# Shape before cleaning:  (197542, 20)
# Shape after cleaning:  (197542, 20)
#    transaction_id                     transaction_token   user_id  \
# 0         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 1          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 2         1219464  b4c967f7-e82d-4a33-a251-a6cb82b339e2  387604.0
# 3         1219465  779bba4c-ff28-40df-8d30-2d4ea4a45cc5  387604.0
# 4          775986  4e3037c7-2597-4c44-808f-6f68963a6e1a  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 1  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 2  2lr1bK6ZNm36FHHh1xWNL1            108050        NaN   NaN  1639411227473
# 3  8PbBly3e13M739zExxyczD            108046        NaN   NaN  1639411238461
# 4  2P5i2sCDZuoarjyFyM6F1n             87512        NaN   NaN  1630481009625
#
#     commit_time user_agent validation solution type  learn_session_id  \
# 0           NaN    unknown        NaN      NaN  NaN             70380
# 1           NaN    unknown        NaN      NaN  NaN             44450
# 2  1.639411e+12    unknown       SKIP      NaN  NaN             84083
# 3           NaN    unknown        NaN      NaN  NaN             84083
# 4  1.630481e+12    unknown       SKIP      NaN  NaN             41319
#
#    topic_id  max_num_tasks  is_closed  type_id  is_accepted  num_checks
# 0         3              5          1        2          NaN           1
# 1      3119              5          1        2          NaN           1
# 2         3              5          1        2          NaN           2
# 3         3              5          1        2          NaN           2
# 4         3              5          1        2          NaN           4

# %% [markdown]
# ### Cleaning criteria 2
# Removing untrackable students: those who never did any training question or theory reading.
# Justification of the cleaning decision: our goal is to predict user's success in level checks based on their regularity in time. As a consequence, we are not interested in users that have not perform any training or preparation for the level checks because we cannot measure their regularity (since they have not used the platform).

# %% [markdown]
# Merging `df` with `events`:

# %%
df = df.merge(events, on = ['transaction_token', 'user_id'])
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 1         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 2          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 3          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 4         1219464  b4c967f7-e82d-4a33-a251-a6cb82b339e2  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 1  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 2  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 3  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 4  2lr1bK6ZNm36FHHh1xWNL1            108050        NaN   NaN  1639411227473
#
#     commit_time user_agent  ... type_id is_accepted num_checks  event_id  \
# 0           NaN    unknown  ...       2         NaN          1   1551821
# 1           NaN    unknown  ...       2         NaN          1   1551834
# 2           NaN    unknown  ...       2         NaN          1    368387
# 3           NaN    unknown  ...       2         NaN          1    368388
# 4  1.639411e+12    unknown  ...       2         NaN          2   2164574
#
#        timestamp  category       action  event_type  session_id  tracking_data
# 0  1637146635291   SESSION  REVIEW_TASK        VIEW     70380.0            NaN
# 1  1637146648711   SESSION        CLOSE       CLICK     70380.0            NaN
# 2  1631200106259   SESSION  REVIEW_TASK        VIEW     44450.0            NaN
# 3  1631200111299   SESSION        CLOSE       CLICK     44450.0            NaN
# 4  1639411227584   SESSION  REVIEW_TASK        VIEW     84083.0            NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# Computing the number of questions submitted by each user on the platform:

# %%
test_data = pd.DataFrame(df.groupby(['user_id', 'action']).size())
test_data = test_data.reset_index()
test_data = test_data[test_data['action'] == ('SUBMIT_ANSWER' or 'GO_TO_THEORY')]
test_data = test_data.rename(columns = {0 : "num_participations"}, errors = "raise")
test_data = test_data.drop(columns = ['action'])
test_data.head()
# Out:
#      user_id  num_participations
# 3   387604.0                   1
# 6   387605.0                  29
# 9   387608.0                  23
# 12  387644.0                  12
# 17  387712.0                  20

# %% [markdown]
# Merging `df` with `test_data`:

# %%
df = df.merge(test_data, on = 'user_id')
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 1         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 2          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 3          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 4         1219464  b4c967f7-e82d-4a33-a251-a6cb82b339e2  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 1  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 2  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 3  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 4  2lr1bK6ZNm36FHHh1xWNL1            108050        NaN   NaN  1639411227473
#
#     commit_time user_agent  ... is_accepted num_checks event_id  \
# 0           NaN    unknown  ...         NaN          1  1551821
# 1           NaN    unknown  ...         NaN          1  1551834
# 2           NaN    unknown  ...         NaN          1   368387
# 3           NaN    unknown  ...         NaN          1   368388
# 4  1.639411e+12    unknown  ...         NaN          2  2164574
#
#        timestamp  category       action  event_type  session_id  \
# 0  1637146635291   SESSION  REVIEW_TASK        VIEW     70380.0
# 1  1637146648711   SESSION        CLOSE       CLICK     70380.0
# 2  1631200106259   SESSION  REVIEW_TASK        VIEW     44450.0
# 3  1631200111299   SESSION        CLOSE       CLICK     44450.0
# 4  1639411227584   SESSION  REVIEW_TASK        VIEW     84083.0
#
#    tracking_data  num_participations
# 0            NaN                   1
# 1            NaN                   1
# 2            NaN                   1
# 3            NaN                   1
# 4            NaN                   1
#
# [5 rows x 28 columns]

# %% [markdown]
# Histogram of the number of *participations* performed by the users of the platform:

# %%
num_participations = df['num_participations'].value_counts(dropna=False)
num_checks.plot(
   kind="hist",
   figsize=(8,5),
   title = "Histogram of Participations"
)
# Out:
# <AxesSubplot:title={'center':'Histogram of Participations'}, ylabel='Frequency'>

# %% [markdown]
# Removing users who have never performed a training question or have not read any theory on the platform:

# %%
# Printing the shape of the framework before the cleaning process:
print("Shape before cleaning: ", df.shape)

# Cleaning the data...
df = df[df['num_participations'] > 0]

# Printing the shape of the framework after the cleaning process:
print("Shape after cleaning: ", df.shape)
df.head()
# Out:
# Shape before cleaning:  (334488, 28)
# Shape after cleaning:  (334488, 28)
#    transaction_id                     transaction_token   user_id  \
# 0         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 1         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 2          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 3          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 4         1219464  b4c967f7-e82d-4a33-a251-a6cb82b339e2  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 1  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 2  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 3  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 4  2lr1bK6ZNm36FHHh1xWNL1            108050        NaN   NaN  1639411227473
#
#     commit_time user_agent  ... is_accepted num_checks event_id  \
# 0           NaN    unknown  ...         NaN          1  1551821
# 1           NaN    unknown  ...         NaN          1  1551834
# 2           NaN    unknown  ...         NaN          1   368387
# 3           NaN    unknown  ...         NaN          1   368388
# 4  1.639411e+12    unknown  ...         NaN          2  2164574
#
#        timestamp  category       action  event_type  session_id  \
# 0  1637146635291   SESSION  REVIEW_TASK        VIEW     70380.0
# 1  1637146648711   SESSION        CLOSE       CLICK     70380.0
# 2  1631200106259   SESSION  REVIEW_TASK        VIEW     44450.0
# 3  1631200111299   SESSION        CLOSE       CLICK     44450.0
# 4  1639411227584   SESSION  REVIEW_TASK        VIEW     84083.0
#
#    tracking_data  num_participations
# 0            NaN                   1
# 1            NaN                   1
# 2            NaN                   1
# 3            NaN                   1
# 4            NaN                   1
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Cleaning criteria 3
# Removing inactive students: those who have not used the platform for several weeks with a minimum number of actions per week.

# %% [markdown]
# Adding `week_of_year` to the dataframe:

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], unit = 'ms')
df['week_of_year'] = df['timestamp'].dt.isocalendar().week
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 1         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 2          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 3          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 4         1219464  b4c967f7-e82d-4a33-a251-a6cb82b339e2  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 1  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 2  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 3  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 4  2lr1bK6ZNm36FHHh1xWNL1            108050        NaN   NaN  1639411227473
#
#     commit_time user_agent  ... num_checks event_id               timestamp  \
# 0           NaN    unknown  ...          1  1551821 2021-11-17 10:57:15.291
# 1           NaN    unknown  ...          1  1551834 2021-11-17 10:57:28.711
# 2           NaN    unknown  ...          1   368387 2021-09-09 15:08:26.259
# 3           NaN    unknown  ...          1   368388 2021-09-09 15:08:31.299
# 4  1.639411e+12    unknown  ...          2  2164574 2021-12-13 16:00:27.584
#
#    category       action  event_type  session_id  tracking_data  \
# 0   SESSION  REVIEW_TASK        VIEW     70380.0            NaN
# 1   SESSION        CLOSE       CLICK     70380.0            NaN
# 2   SESSION  REVIEW_TASK        VIEW     44450.0            NaN
# 3   SESSION        CLOSE       CLICK     44450.0            NaN
# 4   SESSION  REVIEW_TASK        VIEW     84083.0            NaN
#
#    num_participations  week_of_year
# 0                   1            46
# 1                   1            46
# 2                   1            36
# 3                   1            36
# 4                   1            50
#
# [5 rows x 29 columns]

# %% [markdown]
# Adding `week_min` to the dataframe:

# %%
test_data = df[['user_id', 'week_of_year']]
test_data = test_data.groupby(['user_id']).aggregate(lambda x: np.min(np.array(list(x)))).reset_index()
test_data = test_data.rename(columns = {"week_of_year" : "week_min"}, errors = "raise")
test_data.head()
# Out:
#     user_id  week_min
# 0  387604.0        35
# 1  387605.0        26
# 2  387608.0         6
# 3  387644.0        47
# 4  387712.0        47

# %% [markdown]
# Merging `df` with `test_data`:

# %%
df = df.merge(test_data, on = 'user_id')
df['week'] = df['week_of_year'] - df['week_min']
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 1         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 2          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 3          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 4         1219464  b4c967f7-e82d-4a33-a251-a6cb82b339e2  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 1  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 2  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 3  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 4  2lr1bK6ZNm36FHHh1xWNL1            108050        NaN   NaN  1639411227473
#
#     commit_time user_agent  ...               timestamp category       action  \
# 0           NaN    unknown  ... 2021-11-17 10:57:15.291  SESSION  REVIEW_TASK
# 1           NaN    unknown  ... 2021-11-17 10:57:28.711  SESSION        CLOSE
# 2           NaN    unknown  ... 2021-09-09 15:08:26.259  SESSION  REVIEW_TASK
# 3           NaN    unknown  ... 2021-09-09 15:08:31.299  SESSION        CLOSE
# 4  1.639411e+12    unknown  ... 2021-12-13 16:00:27.584  SESSION  REVIEW_TASK
#
#    event_type  session_id  tracking_data  num_participations  week_of_year  \
# 0        VIEW     70380.0            NaN                   1            46
# 1       CLICK     70380.0            NaN                   1            46
# 2        VIEW     44450.0            NaN                   1            36
# 3       CLICK     44450.0            NaN                   1            36
# 4        VIEW     84083.0            NaN                   1            50
#
#    week_min  week
# 0        35    11
# 1        35    11
# 2        35     1
# 3        35     1
# 4        35    15
#
# [5 rows x 31 columns]

# %% [markdown]
# Dropping unnecessary columns:

# %%
df = df.drop(columns = ['week_of_year', 'week_min'])
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 1         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 2          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 3          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 4         1219464  b4c967f7-e82d-4a33-a251-a6cb82b339e2  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 1  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 2  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 3  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 4  2lr1bK6ZNm36FHHh1xWNL1            108050        NaN   NaN  1639411227473
#
#     commit_time user_agent  ... num_checks event_id               timestamp  \
# 0           NaN    unknown  ...          1  1551821 2021-11-17 10:57:15.291
# 1           NaN    unknown  ...          1  1551834 2021-11-17 10:57:28.711
# 2           NaN    unknown  ...          1   368387 2021-09-09 15:08:26.259
# 3           NaN    unknown  ...          1   368388 2021-09-09 15:08:31.299
# 4  1.639411e+12    unknown  ...          2  2164574 2021-12-13 16:00:27.584
#
#    category       action  event_type  session_id  tracking_data  \
# 0   SESSION  REVIEW_TASK        VIEW     70380.0            NaN
# 1   SESSION        CLOSE       CLICK     70380.0            NaN
# 2   SESSION  REVIEW_TASK        VIEW     44450.0            NaN
# 3   SESSION        CLOSE       CLICK     44450.0            NaN
# 4   SESSION  REVIEW_TASK        VIEW     84083.0            NaN
#
#    num_participations  week
# 0                   1    11
# 1                   1    11
# 2                   1     1
# 3                   1     1
# 4                   1    15
#
# [5 rows x 29 columns]

# %% [markdown]
# Let's explore the different types of actions we have in our dataset:

# %%
set(df['action'])
# Out:
# {'CLOSE',
#  'GO_TO_BUG_REPORT',
#  'REVIEW_TASK',
#  'SHARE',
#  'SKIP',
#  'SUBMIT_ANSWER',
#  'VIEW_QUESTION'}

# %% [markdown]
# The actions `GO_TO_BUG_REPORT`, `REVIEW_TASK`, `SUBMIT_ANSWER` and `VIEW_QUESTION` will be considered as **significant actions**, while we won't be interested in actions such as `CLOSE`, `SHARE` and `SKIP`.

# %% [markdown]
# Computing *significant actions* per week:

# %%
test_data = df[['user_id', 'week', 'action']]
# Removing data rows whose action is not significant:
test_data = test_data[test_data['action'].isin(['GO_TO_BUG_REPORT', 'REVIEW_TASK', 'SUBMIT_ANSWER', 'VIEW_QUESTION'])]
test_data = df.groupby(['user_id', 'week']).size()
test_data = pd.DataFrame(test_data)
test_data = test_data.reset_index()
test_data = test_data.rename(columns = {0 : "num_actions_per_week"}, errors = "raise")
test_data.head()
# Out:
#     user_id  week  num_actions_per_week
# 0  387604.0     0                     9
# 1  387604.0     1                     2
# 2  387604.0     3                     5
# 3  387604.0    11                     4
# 4  387604.0    15                     4

# %% [markdown]
# Sorting the values of the dataframe `test_data`:

# %%
test_data = test_data.sort_values(['user_id', 'week'])
test_data.head()
# Out:
#     user_id  week  num_actions_per_week
# 0  387604.0     0                     9
# 1  387604.0     1                     2
# 2  387604.0     3                     5
# 3  387604.0    11                     4
# 4  387604.0    15                     4

# %% [markdown]
# Merging `df` with `test_data`:

# %%
df = df.merge(test_data, on = ['user_id', 'week'])

# Deleting lines with non-significant actions:
df = df[df['action'].isin(['GO_TO_BUG_REPORT', 'REVIEW_TASK', 'SUBMIT_ANSWER', 'VIEW_QUESTION'])]

df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 2         1062122  38ec8cb3-bb73-496b-a324-040e1e60f1a2  387604.0
# 4          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 6         1219464  b4c967f7-e82d-4a33-a251-a6cb82b339e2  387604.0
# 8         1219465  779bba4c-ff28-40df-8d30-2d4ea4a45cc5  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 2   Y6X2CySYGr6cHodeQQnSx             85783        NaN   NaN  1637147092305
# 4  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 6  2lr1bK6ZNm36FHHh1xWNL1            108050        NaN   NaN  1639411227473
# 8  8PbBly3e13M739zExxyczD            108046        NaN   NaN  1639411238461
#
#     commit_time user_agent  ... event_id               timestamp category  \
# 0           NaN    unknown  ...  1551821 2021-11-17 10:57:15.291  SESSION
# 2           NaN    unknown  ...  1552316 2021-11-17 11:04:52.372  SESSION
# 4           NaN    unknown  ...   368387 2021-09-09 15:08:26.259  SESSION
# 6  1.639411e+12    unknown  ...  2164574 2021-12-13 16:00:27.584  SESSION
# 8           NaN    unknown  ...  2164576 2021-12-13 16:00:38.550  SESSION
#
#         action  event_type  session_id  tracking_data  num_participations  \
# 0  REVIEW_TASK        VIEW     70380.0            NaN                   1
# 2  REVIEW_TASK        VIEW     70395.0            NaN                   1
# 4  REVIEW_TASK        VIEW     44450.0            NaN                   1
# 6  REVIEW_TASK        VIEW     84083.0            NaN                   1
# 8  REVIEW_TASK        VIEW     84083.0            NaN                   1
#
#    week  num_actions_per_week
# 0    11                     4
# 2    11                     4
# 4     1                     2
# 6    15                     4
# 8    15                     4
#
# [5 rows x 30 columns]

# %% [markdown]
# Now, I will summarize the data using a boxplot:

# %%
sns.boxplot(x = df['num_actions_per_week'])
# Out:
# <AxesSubplot:xlabel='num_actions_per_week'>

# %% [markdown]
# We can appreciate in the boxplot the presence of outliers. However, we don't want to remove users with a high activity in the platform, as they can provide us with useful information in our research.
#
# As we can appreciate in the plot, there are not outliers in the left side of the plot.

# %% [markdown]
# Now, I will calculate the mean and the standard deviation of the column `num_actions_per_week`:

# %%
mean_actions = df['num_actions_per_week'].mean()
std_actions = df['num_actions_per_week'].std()
print("Mean of the number of significant actions per week: ", mean_actions)
print("Standard deviation of the number of significant actions per week: ", std_actions)
# Out:
# Mean of the number of significant actions per week:  94.37065607902636
# Standard deviation of the number of significant actions per week:  93.24455363724809

# %% [markdown]
# With that, we can obtain the following lower bound:

# %%
lower_bound = mean_actions - std_actions
print("Lower bound that will be used to remove inactive students: ", lower_bound)
# Out:
# Lower bound that will be used to remove inactive students:  1.1261024417782721

# %% [markdown]
# Deleting rows corresponding to weeks with less than `lower_bound` activities performed:

# %%
# Printing the shape of the framework before the cleaning:
print("Shape before cleaning: ", df.shape)

# Cleaning process
df = df[df['num_actions_per_week'] > lower_bound]

# Printing the shape of the framework after the cleaning:
print("Shape after cleaning: ", df.shape)
df.head()
# Out:
# Shape before cleaning:  (304506, 30)
# Shape after cleaning:  (304286, 30)
#    transaction_id                     transaction_token   user_id  \
# 0         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 2         1062122  38ec8cb3-bb73-496b-a324-040e1e60f1a2  387604.0
# 4          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 6         1219464  b4c967f7-e82d-4a33-a251-a6cb82b339e2  387604.0
# 8         1219465  779bba4c-ff28-40df-8d30-2d4ea4a45cc5  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 2   Y6X2CySYGr6cHodeQQnSx             85783        NaN   NaN  1637147092305
# 4  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 6  2lr1bK6ZNm36FHHh1xWNL1            108050        NaN   NaN  1639411227473
# 8  8PbBly3e13M739zExxyczD            108046        NaN   NaN  1639411238461
#
#     commit_time user_agent  ... event_id               timestamp category  \
# 0           NaN    unknown  ...  1551821 2021-11-17 10:57:15.291  SESSION
# 2           NaN    unknown  ...  1552316 2021-11-17 11:04:52.372  SESSION
# 4           NaN    unknown  ...   368387 2021-09-09 15:08:26.259  SESSION
# 6  1.639411e+12    unknown  ...  2164574 2021-12-13 16:00:27.584  SESSION
# 8           NaN    unknown  ...  2164576 2021-12-13 16:00:38.550  SESSION
#
#         action  event_type  session_id  tracking_data  num_participations  \
# 0  REVIEW_TASK        VIEW     70380.0            NaN                   1
# 2  REVIEW_TASK        VIEW     70395.0            NaN                   1
# 4  REVIEW_TASK        VIEW     44450.0            NaN                   1
# 6  REVIEW_TASK        VIEW     84083.0            NaN                   1
# 8  REVIEW_TASK        VIEW     84083.0            NaN                   1
#
#    week  num_actions_per_week
# 0    11                     4
# 2    11                     4
# 4     1                     2
# 6    15                     4
# 8    15                     4
#
# [5 rows x 30 columns]

# %%
df.tail()
# Out:
#         transaction_id                     transaction_token   user_id  \
# 334482         1584551  7c9956b4-d2e2-4f30-9245-8155d6636bd5  404604.0
# 334484         1584578  7e328437-52df-4697-94e9-186844c3e269  404604.0
# 334485         1584578  7e328437-52df-4697-94e9-186844c3e269  404604.0
# 334486         1584584  48c02063-8c99-4e2c-b783-b626cf2fcfe9  404604.0
# 334487         1584584  48c02063-8c99-4e2c-b783-b626cf2fcfe9  404604.0
#
#                    document_id  document_version evaluation  \
# 334482  9wGXbOQkPdV6yr6aUa4ubj             89818        NaN
# 334484  a1jzfZLIHDt7LzD8KKha54             39046    PARTIAL
# 334485  a1jzfZLIHDt7LzD8KKha54             39046    PARTIAL
# 334486   AUaU88i0ME6XdsMZWd5gp             39050    PARTIAL
# 334487   AUaU88i0ME6XdsMZWd5gp             39050    PARTIAL
#
#                                                     input     start_time  \
# 334482                                                NaN  1645454941994
# 334484  {"type": "MULTIPLE_CHOICE", "selections": {"3"...  1645455097067
# 334485  {"type": "MULTIPLE_CHOICE", "selections": {"3"...  1645455097067
# 334486  {"type": "MULTIPLE_CHOICE", "selections": {"0"...  1645455137205
# 334487  {"type": "MULTIPLE_CHOICE", "selections": {"0"...  1645455137205
#
#          commit_time user_agent  ... event_id               timestamp  \
# 334482  1.645455e+12    unknown  ...  3509227 2022-02-21 14:49:02.296
# 334484  1.645455e+12    unknown  ...  3509288 2022-02-21 14:51:37.334
# 334485  1.645455e+12    unknown  ...  3509300 2022-02-21 14:52:16.634
# 334486  1.645461e+12    unknown  ...  3509301 2022-02-21 14:52:17.465
# 334487  1.645461e+12    unknown  ...  3510838 2022-02-21 16:33:16.870
#
#        category         action  event_type  session_id  tracking_data  \
# 334482  SESSION    REVIEW_TASK        VIEW    112060.0            NaN
# 334484  SESSION    REVIEW_TASK        VIEW    112060.0            NaN
# 334485     TASK  SUBMIT_ANSWER       CLICK    112060.0            NaN
# 334486  SESSION    REVIEW_TASK        VIEW    112060.0            NaN
# 334487     TASK  SUBMIT_ANSWER       CLICK    112060.0            NaN
#
#         num_participations  week  num_actions_per_week
# 334482                   4     0                    17
# 334484                   4     0                    17
# 334485                   4     0                    17
# 334486                   4     0                    17
# 334487                   4     0                    17
#
# [5 rows x 30 columns]

# %% [markdown]
# *Definition:* A **significant week** of a particular user is a week in which that user has performed at least $2$ (the closer integer to the lower bound we have defined aboved) significant actions. Note that we have just deleted of our dataframe of the weeks that are not significant.

# %% [markdown]
# Computing the total number of weeks that each user has been actived in the platform:

# %%
test_data = df[['user_id', 'week']].drop_duplicates()
test_data.head()
# Out:
#      user_id  week
# 0   387604.0    11
# 4   387604.0     1
# 6   387604.0    15
# 10  387604.0     0
# 19  387604.0     3

# %%
test_data = pd.DataFrame(test_data.groupby(['user_id']).size()).reset_index()
test_data = test_data.rename(columns = {0 : "num_weeks_per_user"}, errors = "raise")
test_data.head()
# Out:
#     user_id  num_weeks_per_user
# 0  387604.0                   5
# 1  387605.0                   3
# 2  387608.0                   4
# 3  387644.0                   2
# 4  387712.0                   1

# %%
test_data.tail()
# Out:
#        user_id  num_weeks_per_user
# 4397  404583.0                   1
# 4398  404585.0                   1
# 4399  404586.0                   1
# 4400  404592.0                   1
# 4401  404604.0                   1

# %% [markdown]
# Merging `df` with `test_data`:

# %%
df = df.merge(test_data, on = 'user_id')
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 1         1062122  38ec8cb3-bb73-496b-a324-040e1e60f1a2  387604.0
# 2          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 3         1219464  b4c967f7-e82d-4a33-a251-a6cb82b339e2  387604.0
# 4         1219465  779bba4c-ff28-40df-8d30-2d4ea4a45cc5  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 1   Y6X2CySYGr6cHodeQQnSx             85783        NaN   NaN  1637147092305
# 2  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 3  2lr1bK6ZNm36FHHh1xWNL1            108050        NaN   NaN  1639411227473
# 4  8PbBly3e13M739zExxyczD            108046        NaN   NaN  1639411238461
#
#     commit_time user_agent  ...               timestamp category       action  \
# 0           NaN    unknown  ... 2021-11-17 10:57:15.291  SESSION  REVIEW_TASK
# 1           NaN    unknown  ... 2021-11-17 11:04:52.372  SESSION  REVIEW_TASK
# 2           NaN    unknown  ... 2021-09-09 15:08:26.259  SESSION  REVIEW_TASK
# 3  1.639411e+12    unknown  ... 2021-12-13 16:00:27.584  SESSION  REVIEW_TASK
# 4           NaN    unknown  ... 2021-12-13 16:00:38.550  SESSION  REVIEW_TASK
#
#    event_type  session_id  tracking_data  num_participations  week  \
# 0        VIEW     70380.0            NaN                   1    11
# 1        VIEW     70395.0            NaN                   1    11
# 2        VIEW     44450.0            NaN                   1     1
# 3        VIEW     84083.0            NaN                   1    15
# 4        VIEW     84083.0            NaN                   1    15
#
#    num_actions_per_week  num_weeks_per_user
# 0                     4                   5
# 1                     4                   5
# 2                     2                   5
# 3                     4                   5
# 4                     4                   5
#
# [5 rows x 31 columns]

# %% [markdown]
# Now, I will summarize the data using a boxplot:

# %%
sns.boxplot(x = df['num_weeks_per_user'])
# Out:
# <AxesSubplot:xlabel='num_weeks_per_user'>

# %% [markdown]
# We can appreciate in the boxplot the presence of outliers. However, we don't want to remove users with a high activity in the platform, as they can provide us with useful information in our research.
#
# As we can appreciate in the plot, there are not outliers in the left side of the plot.

# %% [markdown]
# Now, I will calculate the mean and the standard deviation of the column `num_weeks_per_user`:

# %%
mean_weeks = df['num_weeks_per_user'].mean()
std_weeks = df['num_weeks_per_user'].std()
print("Mean of the number of significant weeks per user: ", mean_weeks)
print("Standard deviation of the number of significant weeks per user: ", std_weeks)
# Out:
# Mean of the number of significant weeks per user:  3.8323715188999823
# Standard deviation of the number of significant weeks per user:  3.225337587049974

# %% [markdown]
# With that, we can obtain the following lower bound:

# %%
lower_bound = mean_weeks - 0.7*std_weeks
print("Lower bound that will be used to remove inactive students: ", lower_bound)
# Out:
# Lower bound that will be used to remove inactive students:  1.5746352079650006

# %% [markdown]
# Deleting rows corresponding to users with less than `lower_bound` significant weeks:

# %%
# Printing the shape of the framework before the cleaning:
print("Shape before cleaning: ", df.shape)

# Cleaning process...
df = df[df['num_weeks_per_user'] > lower_bound]

# Printing the shape of the framework after the cleaning process:
print("Shape after cleaning: ", df.shape)
df.head()
# Out:
# Shape before cleaning:  (304286, 31)
# Shape after cleaning:  (221418, 31)
#    transaction_id                     transaction_token   user_id  \
# 0         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 1         1062122  38ec8cb3-bb73-496b-a324-040e1e60f1a2  387604.0
# 2          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
# 3         1219464  b4c967f7-e82d-4a33-a251-a6cb82b339e2  387604.0
# 4         1219465  779bba4c-ff28-40df-8d30-2d4ea4a45cc5  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 1   Y6X2CySYGr6cHodeQQnSx             85783        NaN   NaN  1637147092305
# 2  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
# 3  2lr1bK6ZNm36FHHh1xWNL1            108050        NaN   NaN  1639411227473
# 4  8PbBly3e13M739zExxyczD            108046        NaN   NaN  1639411238461
#
#     commit_time user_agent  ...               timestamp category       action  \
# 0           NaN    unknown  ... 2021-11-17 10:57:15.291  SESSION  REVIEW_TASK
# 1           NaN    unknown  ... 2021-11-17 11:04:52.372  SESSION  REVIEW_TASK
# 2           NaN    unknown  ... 2021-09-09 15:08:26.259  SESSION  REVIEW_TASK
# 3  1.639411e+12    unknown  ... 2021-12-13 16:00:27.584  SESSION  REVIEW_TASK
# 4           NaN    unknown  ... 2021-12-13 16:00:38.550  SESSION  REVIEW_TASK
#
#    event_type  session_id  tracking_data  num_participations  week  \
# 0        VIEW     70380.0            NaN                   1    11
# 1        VIEW     70395.0            NaN                   1    11
# 2        VIEW     44450.0            NaN                   1     1
# 3        VIEW     84083.0            NaN                   1    15
# 4        VIEW     84083.0            NaN                   1    15
#
#    num_actions_per_week  num_weeks_per_user
# 0                     4                   5
# 1                     4                   5
# 2                     2                   5
# 3                     4                   5
# 4                     4                   5
#
# [5 rows x 31 columns]
