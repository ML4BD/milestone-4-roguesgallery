# %% [markdown]
# # Data preprocessing Part II

# %%
# Import the tables of the data set as dataframes.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATA_DIR = './data' # Directory where the data is located
greyscale = ['#808080', '#929591']

# %%
learn_sessions_transactions = pd.read_csv('{}/learn_sessions_transactions.csv.gz'.format(DATA_DIR))
users = pd.read_csv('{}/users.csv.gz'.format(DATA_DIR))
events = pd.read_csv('{}/events.csv.gz'.format(DATA_DIR))
transactions = pd.read_csv('{}/transactions.csv.gz'.format(DATA_DIR))

# %%
print("Printing the shapes of the dataframes...")
print("Number of rows of the learn_sessions_transactions dataframe:", learn_sessions_transactions.shape[0])
print("Number of rows of the users dataframe:", users.shape[0])
print("Number of rows of the events dataframe:", events.shape[0])
print("Number of rows of the transactions dataframe:", transactions.shape[0])
# Out:
# Printing the shapes of the dataframes...
# Number of rows of the learn_sessions_transactions dataframe: 502921
# Number of rows of the users dataframe: 13790
# Number of rows of the events dataframe: 3465559
# Number of rows of the transactions dataframe: 800018

# %%
def remove_users(events, transactions):
    tokens_event = set(events['transaction_token'].unique())
    print("{} tokens in events".format(len(tokens_event)))

    tokens_trans = set(transactions['transaction_token'].unique())
    print("{} tokens in transactions".format(len(tokens_trans)))

    missing_tokens = list(tokens_event - tokens_trans)
    missing_tokens.remove(np.nan)
    print("{} tokens in events but not in transactions".format(len(missing_tokens)))

    users_missing = list(events[events['transaction_token'].isin(missing_tokens)]['user_id'].unique())
    print("{} users in events but not in transactions".format(len(users_missing)))

    # Events without missing users. Equivalent to removing the missing tokens from events.
    len_events = len(events)
    events = events[~events['user_id'].isin(users_missing)]
    stat_events = (len_events - len(events))/len_events
    print("{}% of events eliminated".format(round(stat_events, 4)))

    return events, transactions
events, transactions = remove_users(events, transactions)
# Out:
# 637678 tokens in events
# 800018 tokens in transactions
# 37685 tokens in events but not in transactions
# 1304 users in events but not in transactions
# 0.0595% of events eliminated

# %% [markdown]
# Merging `users` with `events`:

# %%
df_exploratory = users.merge(events, on = 'user_id')

# %% [markdown]
# Small exploratory analysis of the gender of the users of the platform:

# %%
df_exploratory = pd.DataFrame(df_exploratory.groupby(['user_id']).size())
df_exploratory = df_exploratory.rename(columns = {0 : "count"}, errors = "raise")
df_exploratory.head()
# Out:
#          count
# user_id
# 387604    2606
# 387605    3331
# 387608     866
# 387615     492
# 387643       4

# %%
df_exploratory = users.merge(df_exploratory, on = 'user_id').drop(columns = ['count'])
df_exploratory.head()
# Out:
#    user_id gender canton          class_level class_code
# 0   387604    NaN    NaN                  NaN        NaN
# 1   387605    NaN    NaN                  NaN        NaN
# 2   387608    NaN    NaN                  NaN      9Q2M7
# 3   387615   MALE     SG  Gymnasium - 3. Jahr        NaN
# 4   387643    NaN    NaN                  NaN        NaN

# %%
ax = sns.countplot(data=df_exploratory, x= 'gender', order = df_exploratory['gender'].value_counts().index, color = greyscale[0])
ax.set(xlabel='Gender', ylabel='Count')
ax.get_figure().savefig("num_per_gender.jpg")

# %%
val_counts = df_exploratory.gender.value_counts()/np.sum(df_exploratory.gender.value_counts())
labels = val_counts.index.to_list()
plt.pie(val_counts, labels = labels,autopct='%1.1f%%')
plt.savefig('pie_chart.jpg')
# Out:
# /tmp/ipykernel_106/3966163830.py:3: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   plt.pie(val_counts, labels = labels,autopct='%1.1f%%')

# %% [markdown]
# Now, the five most popular levels in the swiss school system of the students of the platform will be shown:

# %%
levels = df_exploratory['class_level'].value_counts(dropna=False).head(10)
df_1 = pd.DataFrame({"Level": levels.index, "Count": levels.tolist(), "Count %": levels.tolist()/np.sum(levels.tolist()) })

# %%
df_1.head()
# Out:
#                          Level  Count   Count %
# 0          Gymnasium - 1. Jahr   1535  0.240332
# 1                          NaN   1167  0.182715
# 2          Gymnasium - 2. Jahr   1040  0.162831
# 3  Kurzzeitgymnasium - 1. Jahr    734  0.114921
# 4  Langzeitgymnasium - 3. Jahr    379  0.059339

# %% [markdown]
# Merging `learn_sessions_transactions` dataframe with `transactions` dataframe:

# %%
df = transactions.merge(learn_sessions_transactions, on = 'transaction_id')
# Printing the original shape of the data
print("Original shape of the data: ", df.shape)

df.head()
# Out:
# Original shape of the data:  (497263, 19)
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1          563378  b5978bb1-c34f-4157-9d1f-052b451edab5  387604.0
# 2         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 3          774545  64645a54-a4f3-4e7b-9f88-39205882d87d  387604.0
# 4          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  1aRVNzqunJs6eJCo9vZiy3             70675        NaN   NaN  1615192571101
# 2  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 3  1eWCmfpLnkQ96qFQp5XixR             95079        NaN   NaN  1630399544151
# 4  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
#
#     commit_time user_agent validation solution type  learn_session_id  \
# 0  1.645197e+12    unknown       SKIP      NaN  NaN            111059
# 1           NaN    unknown        NaN      NaN  NaN             14120
# 2           NaN    unknown        NaN      NaN  NaN             70380
# 3  1.630400e+12    unknown       SKIP      NaN  NaN             41166
# 4           NaN    unknown        NaN      NaN  NaN             44450
#
#    topic_id  max_num_tasks  is_closed  type_id  is_accepted
# 0      3250              5          0        1          NaN
# 1         3              5          1        1          1.0
# 2         3              5          1        2          NaN
# 3      3119              5          1        1          1.0
# 4      3119              5          1        2          NaN

# %% [markdown]
# ### Cleaning criteria 1
# Removing inactive students: those who did not perform any level check.
# Justification of the cleaning decision: our goal is to predict user's success in level checks based on their regularity in time. As a consequence, we are not interested in users who did not perform any level check.

# %% [markdown]
# Computing the number of checks performed by each user on the platform:

# %%
test_data = pd.DataFrame(df.groupby(['user_id', 'type_id']).size())
test_data = test_data.reset_index()
test_data = test_data[test_data['type_id'] == 2]
test_data = test_data.rename(columns = {0 : "num_checks"}, errors = "raise")
test_data = test_data.drop(columns = ['type_id'])
test_data.head()
# Out:
#     user_id  num_checks
# 1  387604.0          11
# 3  387605.0          77
# 5  387608.0          53
# 7  387615.0         101
# 8  387643.0          15

# %% [markdown]
# Merging `df` with `test_data`:

# %%
df = df.merge(test_data, on = ['user_id'])
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1          563378  b5978bb1-c34f-4157-9d1f-052b451edab5  387604.0
# 2         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 3          774545  64645a54-a4f3-4e7b-9f88-39205882d87d  387604.0
# 4          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  1aRVNzqunJs6eJCo9vZiy3             70675        NaN   NaN  1615192571101
# 2  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 3  1eWCmfpLnkQ96qFQp5XixR             95079        NaN   NaN  1630399544151
# 4  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
#
#     commit_time user_agent validation solution type  learn_session_id  \
# 0  1.645197e+12    unknown       SKIP      NaN  NaN            111059
# 1           NaN    unknown        NaN      NaN  NaN             14120
# 2           NaN    unknown        NaN      NaN  NaN             70380
# 3  1.630400e+12    unknown       SKIP      NaN  NaN             41166
# 4           NaN    unknown        NaN      NaN  NaN             44450
#
#    topic_id  max_num_tasks  is_closed  type_id  is_accepted  num_checks
# 0      3250              5          0        1          NaN          11
# 1         3              5          1        1          1.0          11
# 2         3              5          1        2          NaN          11
# 3      3119              5          1        1          1.0          11
# 4      3119              5          1        2          NaN          11

# %% [markdown]
# Histogram of the number of *level checks* performed by the users of the platform:

# %%
num_checks = df['num_checks'].value_counts(dropna=False)
ax = num_checks.plot(
   kind="hist",
   figsize=(8,5),
   title = "Histogram of Level Checks",
   color=greyscale[1]
)
ax.get_figure().savefig('histogram_level_checks.jpg')

# %% [markdown]
# Removing users who have not performed any level check:

# %%
# Printing the shape of the framework before the cleaning process:
print("Shape before cleaning: ", df.shape)

# Cleaning the data...
df = df[df['num_checks'] > 0]

# Printing the shape of the framework after the cleaning process:
print("Shape after cleaning: ", df.shape)
df.head()
# Out:
# Shape before cleaning:  (425731, 20)
# Shape after cleaning:  (425731, 20)
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1          563378  b5978bb1-c34f-4157-9d1f-052b451edab5  387604.0
# 2         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 3          774545  64645a54-a4f3-4e7b-9f88-39205882d87d  387604.0
# 4          803096  37f3ad9a-ca06-43dc-9878-90599ac31f44  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  1aRVNzqunJs6eJCo9vZiy3             70675        NaN   NaN  1615192571101
# 2  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 3  1eWCmfpLnkQ96qFQp5XixR             95079        NaN   NaN  1630399544151
# 4  1LNLRvfltpl9kmi7YOJIKV             64911        NaN   NaN  1631200106071
#
#     commit_time user_agent validation solution type  learn_session_id  \
# 0  1.645197e+12    unknown       SKIP      NaN  NaN            111059
# 1           NaN    unknown        NaN      NaN  NaN             14120
# 2           NaN    unknown        NaN      NaN  NaN             70380
# 3  1.630400e+12    unknown       SKIP      NaN  NaN             41166
# 4           NaN    unknown        NaN      NaN  NaN             44450
#
#    topic_id  max_num_tasks  is_closed  type_id  is_accepted  num_checks
# 0      3250              5          0        1          NaN          11
# 1         3              5          1        1          1.0          11
# 2         3              5          1        2          NaN          11
# 3      3119              5          1        1          1.0          11
# 4      3119              5          1        2          NaN          11

# %% [markdown]
# Dropping duplicates:

# %%
print("Shape with duplicates:", df.shape)
df = df.drop_duplicates()
print("Shape without duplicates:", df.shape)
# Out:
# Shape with duplicates: (425731, 20)
# Shape without duplicates: (425731, 20)

# %% [markdown]
# Saving intermediate dataframe:

# %%
# Write a pandas dataframe df to gzipped CSV file
df.to_csv("data_1.csv.gz", 
           index=False, 
           compression="gzip")

# %% [markdown]
# ### Cleaning criteria 2
# Removing untrackable students: those who never did any training question or theory reading.
# Justification of the cleaning decision: our goal is to predict user's success in level checks based on their regularity in time. As a consequence, we are not interested in users that have not perform any training or preparation for the level checks because we cannot measure their regularity (since they have not used the platform).

# %% [markdown]
# Merging `df` with `events`:

# %%
df = df.merge(events, on = ['user_id','transaction_token'])
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 2         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 3         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 4          774545  64645a54-a4f3-4e7b-9f88-39205882d87d  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 2  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 3  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 4  1eWCmfpLnkQ96qFQp5XixR             95079        NaN   NaN  1630399544151
#
#     commit_time user_agent  ... type_id is_accepted num_checks  event_id  \
# 0  1.645197e+12    unknown  ...       1         NaN         11   3469683
# 1  1.645197e+12    unknown  ...       1         NaN         11   3469684
# 2           NaN    unknown  ...       2         NaN         11   1551821
# 3           NaN    unknown  ...       2         NaN         11   1551834
# 4  1.630400e+12    unknown  ...       1         1.0         11    231941
#
#        timestamp  category       action  event_type  session_id  tracking_data
# 0  1645197218387   SESSION  REVIEW_TASK        VIEW    111059.0            NaN
# 1  1645197220545   SESSION         SKIP       CLICK    111059.0            NaN
# 2  1637146635291   SESSION  REVIEW_TASK        VIEW     70380.0            NaN
# 3  1637146648711   SESSION        CLOSE       CLICK     70380.0            NaN
# 4  1630399544249   SESSION  REVIEW_TASK        VIEW     41166.0            NaN
#
# [5 rows x 27 columns]

# %%
df.tail()
# Out:
#         transaction_id                     transaction_token   user_id  \
# 949934         1584551  7c9956b4-d2e2-4f30-9245-8155d6636bd5  404604.0
# 949935         1584578  7e328437-52df-4697-94e9-186844c3e269  404604.0
# 949936         1584578  7e328437-52df-4697-94e9-186844c3e269  404604.0
# 949937         1584584  48c02063-8c99-4e2c-b783-b626cf2fcfe9  404604.0
# 949938         1584584  48c02063-8c99-4e2c-b783-b626cf2fcfe9  404604.0
#
#                    document_id  document_version evaluation  \
# 949934  9wGXbOQkPdV6yr6aUa4ubj             89818        NaN
# 949935  a1jzfZLIHDt7LzD8KKha54             39046    PARTIAL
# 949936  a1jzfZLIHDt7LzD8KKha54             39046    PARTIAL
# 949937   AUaU88i0ME6XdsMZWd5gp             39050    PARTIAL
# 949938   AUaU88i0ME6XdsMZWd5gp             39050    PARTIAL
#
#                                                     input     start_time  \
# 949934                                                NaN  1645454941994
# 949935  {"type": "MULTIPLE_CHOICE", "selections": {"3"...  1645455097067
# 949936  {"type": "MULTIPLE_CHOICE", "selections": {"3"...  1645455097067
# 949937  {"type": "MULTIPLE_CHOICE", "selections": {"0"...  1645455137205
# 949938  {"type": "MULTIPLE_CHOICE", "selections": {"0"...  1645455137205
#
#          commit_time user_agent  ... type_id is_accepted num_checks  event_id  \
# 949934  1.645455e+12    unknown  ...       2         1.0          8   3509238
# 949935  1.645455e+12    unknown  ...       2         1.0          8   3509288
# 949936  1.645455e+12    unknown  ...       2         1.0          8   3509300
# 949937  1.645461e+12    unknown  ...       2         1.0          8   3509301
# 949938  1.645461e+12    unknown  ...       2         1.0          8   3510838
#
#             timestamp  category         action  event_type  session_id  \
# 949934  1645454970547   SESSION           SKIP       CLICK    112060.0
# 949935  1645455097334   SESSION    REVIEW_TASK        VIEW    112060.0
# 949936  1645455136634      TASK  SUBMIT_ANSWER       CLICK    112060.0
# 949937  1645455137465   SESSION    REVIEW_TASK        VIEW    112060.0
# 949938  1645461196870      TASK  SUBMIT_ANSWER       CLICK    112060.0
#
#         tracking_data
# 949934            NaN
# 949935            NaN
# 949936            NaN
# 949937            NaN
# 949938            NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# Computing the number of questions submitted by each user on the platform:

# %%
test_data = pd.DataFrame(df.groupby(['user_id', 'action']).size())
test_data = test_data.reset_index()
test_data = test_data[test_data['action'] == ('SUBMIT_ANSWER' or 'GO_TO_THEORY')]
test_data = test_data.rename(columns = {0 : "num_participations"}, errors = "raise")
test_data = test_data.drop(columns = ['action'])
test_data.head()
# Out:
#      user_id  num_participations
# 5   387604.0                   5
# 16  387605.0                 110
# 22  387608.0                  38
# 27  387615.0                   7
# 36  387644.0                  22

# %% [markdown]
# Merging `df` with `test_data`:

# %%
df = df.merge(test_data, on = 'user_id')
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 2         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 3         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 4          774545  64645a54-a4f3-4e7b-9f88-39205882d87d  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 2  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 3  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 4  1eWCmfpLnkQ96qFQp5XixR             95079        NaN   NaN  1630399544151
#
#     commit_time user_agent  ... is_accepted num_checks event_id  \
# 0  1.645197e+12    unknown  ...         NaN         11  3469683
# 1  1.645197e+12    unknown  ...         NaN         11  3469684
# 2           NaN    unknown  ...         NaN         11  1551821
# 3           NaN    unknown  ...         NaN         11  1551834
# 4  1.630400e+12    unknown  ...         1.0         11   231941
#
#        timestamp  category       action  event_type  session_id  \
# 0  1645197218387   SESSION  REVIEW_TASK        VIEW    111059.0
# 1  1645197220545   SESSION         SKIP       CLICK    111059.0
# 2  1637146635291   SESSION  REVIEW_TASK        VIEW     70380.0
# 3  1637146648711   SESSION        CLOSE       CLICK     70380.0
# 4  1630399544249   SESSION  REVIEW_TASK        VIEW     41166.0
#
#    tracking_data  num_participations
# 0            NaN                   5
# 1            NaN                   5
# 2            NaN                   5
# 3            NaN                   5
# 4            NaN                   5
#
# [5 rows x 28 columns]

# %% [markdown]
# Histogram of the number of *participations* performed by the users of the platform:

# %%
num_participations = df['num_participations'].value_counts(dropna=False)
ax = num_participations.plot(
   kind="hist",
   figsize=(8,5),
   title = "Histogram of Participations",
   color=greyscale[1]
)
ax.get_figure().savefig('histogram_num_participations.jpg')

# %% [markdown]
# Removing users who have never performed a training question or have not read any theory on the platform:

# %%
# Printing the shape of the framework before the cleaning process:
print("Shape before cleaning: ", df.shape)

# Cleaning the data...
df = df[df['num_participations'] > 0]

# Printing the shape of the framework after the cleaning process:
print("Shape after cleaning: ", df.shape)
df.head()
# Out:
# Shape before cleaning:  (948029, 28)
# Shape after cleaning:  (948029, 28)
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 2         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 3         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 4          774545  64645a54-a4f3-4e7b-9f88-39205882d87d  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 2  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 3  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 4  1eWCmfpLnkQ96qFQp5XixR             95079        NaN   NaN  1630399544151
#
#     commit_time user_agent  ... is_accepted num_checks event_id  \
# 0  1.645197e+12    unknown  ...         NaN         11  3469683
# 1  1.645197e+12    unknown  ...         NaN         11  3469684
# 2           NaN    unknown  ...         NaN         11  1551821
# 3           NaN    unknown  ...         NaN         11  1551834
# 4  1.630400e+12    unknown  ...         1.0         11   231941
#
#        timestamp  category       action  event_type  session_id  \
# 0  1645197218387   SESSION  REVIEW_TASK        VIEW    111059.0
# 1  1645197220545   SESSION         SKIP       CLICK    111059.0
# 2  1637146635291   SESSION  REVIEW_TASK        VIEW     70380.0
# 3  1637146648711   SESSION        CLOSE       CLICK     70380.0
# 4  1630399544249   SESSION  REVIEW_TASK        VIEW     41166.0
#
#    tracking_data  num_participations
# 0            NaN                   5
# 1            NaN                   5
# 2            NaN                   5
# 3            NaN                   5
# 4            NaN                   5
#
# [5 rows x 28 columns]

# %% [markdown]
# Dropping duplicates:

# %%
print("Shape with duplicates:", df.shape)
df = df.drop_duplicates()
print("Shape without duplicates:", df.shape)
# Out:
# Shape with duplicates: (948029, 28)
# Shape without duplicates: (948029, 28)

# %% [markdown]
# Saving intermediate dataframe:

# %%
# Write a pandas dataframe df to gzipped CSV file
df.to_csv("data_2.csv.gz", 
           index=False, 
           compression="gzip")

# %% [markdown]
# ### Cleaning criteria 3
# Removing inactive students: those who have not used the platform for several weeks with a minimum number of actions per week.

# %% [markdown]
# Adding `week_of_year` to the dataframe:

# %%
def create_week_number(d):
    return (d.isocalendar()[0]-2021)*53 + d.isocalendar()[1]-1

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], unit = 'ms')
df['week'] = df['timestamp'].map(lambda x: create_week_number(x))
df['week'] -= min(df['week'])
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 2         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 3         1062011  411c11ae-6af2-4574-b7df-d94dac280da5  387604.0
# 4          774545  64645a54-a4f3-4e7b-9f88-39205882d87d  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 2  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 3  1DI3PtzowVCafiuZCb0mEX             89020        NaN   NaN  1637146635218
# 4  1eWCmfpLnkQ96qFQp5XixR             95079        NaN   NaN  1630399544151
#
#     commit_time user_agent  ... num_checks event_id               timestamp  \
# 0  1.645197e+12    unknown  ...         11  3469683 2022-02-18 15:13:38.387
# 1  1.645197e+12    unknown  ...         11  3469684 2022-02-18 15:13:40.545
# 2           NaN    unknown  ...         11  1551821 2021-11-17 10:57:15.291
# 3           NaN    unknown  ...         11  1551834 2021-11-17 10:57:28.711
# 4  1.630400e+12    unknown  ...         11   231941 2021-08-31 08:45:44.249
#
#    category       action  event_type  session_id  tracking_data  \
# 0   SESSION  REVIEW_TASK        VIEW    111059.0            NaN
# 1   SESSION         SKIP       CLICK    111059.0            NaN
# 2   SESSION  REVIEW_TASK        VIEW     70380.0            NaN
# 3   SESSION        CLOSE       CLICK     70380.0            NaN
# 4   SESSION  REVIEW_TASK        VIEW     41166.0            NaN
#
#    num_participations  week
# 0                   5    40
# 1                   5    40
# 2                   5    26
# 3                   5    26
# 4                   5    15
#
# [5 rows x 29 columns]

# %%
df.iloc[300]
# Out:
# transaction_id                                     1114001
# transaction_token     1924e4ee-6f6f-4be1-9447-5d389aa08a98
# user_id                                           387605.0
# document_id                         54NBdmRqbZr9y5jrumbGGv
# document_version                                     85083
# evaluation                                             NaN
# input                                                  NaN
# start_time                                   1637914605464
# commit_time                                1637914607100.0
# user_agent                                         unknown
# validation                                            SKIP
# solution                                               NaN
# type                                                   NaN
# learn_session_id                                     74600
# topic_id                                               957
# max_num_tasks                                            5
# is_closed                                                1
# type_id                                                  1
# is_accepted                                            1.0
# num_checks                                              77
# event_id                                           1747463
# timestamp                       2021-11-26 08:16:47.114000
# category                                           SESSION
# action                                                SKIP
# event_type                                           CLICK
# session_id                                         74600.0
# tracking_data                                          NaN
# num_participations                                     110
# week                                                    27
# Name: 300, dtype: object

# %%
df.tail()
# Out:
#         transaction_id                     transaction_token   user_id  \
# 948024         1584551  7c9956b4-d2e2-4f30-9245-8155d6636bd5  404604.0
# 948025         1584578  7e328437-52df-4697-94e9-186844c3e269  404604.0
# 948026         1584578  7e328437-52df-4697-94e9-186844c3e269  404604.0
# 948027         1584584  48c02063-8c99-4e2c-b783-b626cf2fcfe9  404604.0
# 948028         1584584  48c02063-8c99-4e2c-b783-b626cf2fcfe9  404604.0
#
#                    document_id  document_version evaluation  \
# 948024  9wGXbOQkPdV6yr6aUa4ubj             89818        NaN
# 948025  a1jzfZLIHDt7LzD8KKha54             39046    PARTIAL
# 948026  a1jzfZLIHDt7LzD8KKha54             39046    PARTIAL
# 948027   AUaU88i0ME6XdsMZWd5gp             39050    PARTIAL
# 948028   AUaU88i0ME6XdsMZWd5gp             39050    PARTIAL
#
#                                                     input     start_time  \
# 948024                                                NaN  1645454941994
# 948025  {"type": "MULTIPLE_CHOICE", "selections": {"3"...  1645455097067
# 948026  {"type": "MULTIPLE_CHOICE", "selections": {"3"...  1645455097067
# 948027  {"type": "MULTIPLE_CHOICE", "selections": {"0"...  1645455137205
# 948028  {"type": "MULTIPLE_CHOICE", "selections": {"0"...  1645455137205
#
#          commit_time user_agent  ... num_checks event_id  \
# 948024  1.645455e+12    unknown  ...          8  3509238
# 948025  1.645455e+12    unknown  ...          8  3509288
# 948026  1.645455e+12    unknown  ...          8  3509300
# 948027  1.645461e+12    unknown  ...          8  3509301
# 948028  1.645461e+12    unknown  ...          8  3510838
#
#                      timestamp  category         action  event_type  \
# 948024 2022-02-21 14:49:30.547   SESSION           SKIP       CLICK
# 948025 2022-02-21 14:51:37.334   SESSION    REVIEW_TASK        VIEW
# 948026 2022-02-21 14:52:16.634      TASK  SUBMIT_ANSWER       CLICK
# 948027 2022-02-21 14:52:17.465   SESSION    REVIEW_TASK        VIEW
# 948028 2022-02-21 16:33:16.870      TASK  SUBMIT_ANSWER       CLICK
#
#         session_id  tracking_data  num_participations  week
# 948024    112060.0            NaN                   4    41
# 948025    112060.0            NaN                   4    41
# 948026    112060.0            NaN                   4    41
# 948027    112060.0            NaN                   4    41
# 948028    112060.0            NaN                   4    41
#
# [5 rows x 29 columns]

# %% [markdown]
# Let's explore the different types of actions we have in our dataset:

# %%
print(set(df['action']))
# Out:
# {'VIEW_QUESTION', 'REQUEST_HINT', 'CLOSE', 'SHARE', 'GO_TO_COMMENTS', 'NEXT', 'OPEN_FEEDBACK', 'SKIP', 'CLOSE_FEEDBACK', 'GO_TO_THEORY', 'REVIEW_TASK', 'SUBMIT_ANSWER', 'GO_TO_BUG_REPORT'}

# %% [markdown]
# The actions list in the set above will be considered as **significant actions** (this actions are the ones that are in the `events` table but that also have a `transaction_token` associated in the same row), while we won't be interested in actions such as `LOGIN`, `LOGOUT` and `NAVIGATE_DASHBOARD` (see set of actions below).

# %%
print(set(events['action'])-set(df['action']))
# Out:
# {'VIEW_SESSION_END', 'WINDOW_OPEN', 'WINDOW_CLOSE', 'SURVEY_BANNER', 'SELECT_STATISTICS', 'SUBMIT_SEARCH', 'PRETEST', 'PAGE_VISIT', 'REJECT_PROGRESS', 'LOGIN', 'NAVIGATE_SURVEY', 'WINDOW_VISIBLE_FALSE', 'SHARE_SESSION', 'GO_TO_SESSION', 'NAVIGATE_DASHBOARD', 'ACCEPT_PROGRESS', 'LOGOUT', 'WINDOW_VISIBLE_TRUE'}

# %% [markdown]
# Computing *significant actions* per week:

# %%
test_data = df[['user_id', 'week', 'action']]
# Removing data rows whose action is not significant:
test_data = df.groupby(['user_id', 'week']).size()
test_data = pd.DataFrame(test_data)
test_data = test_data.reset_index()
test_data = test_data.rename(columns = {0 : "num_actions_per_week"}, errors = "raise")
test_data.head()
# Out:
#     user_id  week  num_actions_per_week
# 0  387604.0     5                     3
# 1  387604.0     6                    16
# 2  387604.0    13                     2
# 3  387604.0    15                    29
# 4  387604.0    16                     5

# %% [markdown]
# Sorting the values of the dataframe `test_data`:

# %%
test_data = test_data.sort_values(['user_id', 'week'])
test_data.head()
# Out:
#     user_id  week  num_actions_per_week
# 0  387604.0     5                     3
# 1  387604.0     6                    16
# 2  387604.0    13                     2
# 3  387604.0    15                    29
# 4  387604.0    16                     5

# %% [markdown]
# Merging `df` with `test_data`:

# %%
df = df.merge(test_data, on = ['user_id', 'week'])
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 2         1576012  379dad17-2d6f-42f3-b6f0-68a39664733b  387604.0
# 3         1576009  5094da67-0959-46b4-bb4a-03b5d55259fa  387604.0
# 4         1576009  5094da67-0959-46b4-bb4a-03b5d55259fa  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 2  1taQDeFXg1E9GxbT0YApJU            115407        NaN   NaN  1645197222948
# 3  81qKZ40TTAx6YsQPzKE5kx            116432        NaN   NaN  1645197210317
# 4  81qKZ40TTAx6YsQPzKE5kx            116432        NaN   NaN  1645197210317
#
#     commit_time user_agent  ... event_id               timestamp category  \
# 0  1.645197e+12    unknown  ...  3469683 2022-02-18 15:13:38.387  SESSION
# 1  1.645197e+12    unknown  ...  3469684 2022-02-18 15:13:40.545  SESSION
# 2           NaN    unknown  ...  3469687 2022-02-18 15:13:43.057  SESSION
# 3  1.645197e+12    unknown  ...  3469676 2022-02-18 15:13:30.415  SESSION
# 4  1.645197e+12    unknown  ...  3469682 2022-02-18 15:13:37.975  SESSION
#
#         action  event_type  session_id  tracking_data  num_participations  \
# 0  REVIEW_TASK        VIEW    111059.0            NaN                   5
# 1         SKIP       CLICK    111059.0            NaN                   5
# 2  REVIEW_TASK        VIEW    111059.0            NaN                   5
# 3  REVIEW_TASK        VIEW    111059.0            NaN                   5
# 4         SKIP       CLICK    111059.0            NaN                   5
#
#    week  num_actions_per_week
# 0    40                     7
# 1    40                     7
# 2    40                     7
# 3    40                     7
# 4    40                     7
#
# [5 rows x 30 columns]

# %% [markdown]
# Dropping duplicates:

# %%
print("Shape with duplicates:", df.shape)
df = df.drop_duplicates()
print("Shape without duplicates:", df.shape)
# Out:
# Shape with duplicates: (948029, 30)
# Shape without duplicates: (948029, 30)

# %% [markdown]
# Saving intermediate dataframe:

# %%
# Write a pandas dataframe df to gzipped CSV file
df.to_csv("data_3_1.csv.gz", 
           index=False, 
           compression="gzip")

# %% [markdown]
# Histogram of the number of *actions per week* performed by the users of the platform:

# %%
num_actions_per_week = df['num_actions_per_week'].value_counts(dropna=False)
ax = num_actions_per_week.plot(
   kind="hist",
   figsize=(8,5),
   title = "Histogram of Number of Actions per Week",
   color=greyscale[1]
)
ax.get_figure().savefig('histogram_number_of_actions_per_week.jpg')

# %% [markdown]
# Now, I will summarize the data using a boxplot:

# %%
sns.boxplot(x = df['num_actions_per_week'])
# Out:
# <AxesSubplot:xlabel='num_actions_per_week'>

# %% [markdown]
# We can appreciate in the boxplot the presence of outliers. However, we don't want to remove users with a high activity in the platform, as they can provide us with useful information in our research.
#
# As we can appreciate in the plot, there are not outliers in the left side of the plot.

# %% [markdown]
# Now, I will apply the Local Outlier Factor method to detect outliers values of the column `num_actions_per_week`:

# %%
# Import the required library
from sklearn.neighbors import LocalOutlierFactor

# Define LOF class
lof = LocalOutlierFactor() # consider playing around with 'n_neighbors' parameter

test_data = df[['user_id', 'week', 'num_actions_per_week']]

# Predict whether the numerical columns are outlier or not
y_pred = lof.fit_predict(test_data)

# Select all rows that are not outliers
mask = y_pred != -1
print("Shape with local outliers:", test_data.shape)
test_data_clean = test_data[mask]
test_data_clean.head()
print("Shape without local outliers:", test_data.shape)
# Out:
# Shape with local outliers: (948029, 3)
# Shape without local outliers: (948029, 3)

# %% [markdown]
# It turns out that none of the rows have been deleted using this method.

# %% [markdown]
# Dropping duplicates:

# %%
print("Shape with duplicates:", df.shape)
df = df.drop_duplicates()
print("Shape without duplicates:", df.shape)
# Out:
# Shape with duplicates: (948029, 30)
# Shape without duplicates: (948029, 30)

# %% [markdown]
# Saving intermediate dataframe:

# %%
# Write a pandas dataframe df to gzipped CSV file
df.to_csv("data_3_2.csv.gz", 
           index=False, 
           compression="gzip")

# %%
# Printing the shape of the framework before the cleaning:
print("Shape before cleaning: ", df.shape)

# Cleaning process
df = df[df['num_actions_per_week'] > 4]
df.head()

# Printing the shape of the framework after the cleaning:
print("Shape after cleaning: ", df.shape)
df.head()
# Out:
# Shape before cleaning:  (948029, 30)
# Shape after cleaning:  (944645, 30)
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 2         1576012  379dad17-2d6f-42f3-b6f0-68a39664733b  387604.0
# 3         1576009  5094da67-0959-46b4-bb4a-03b5d55259fa  387604.0
# 4         1576009  5094da67-0959-46b4-bb4a-03b5d55259fa  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 2  1taQDeFXg1E9GxbT0YApJU            115407        NaN   NaN  1645197222948
# 3  81qKZ40TTAx6YsQPzKE5kx            116432        NaN   NaN  1645197210317
# 4  81qKZ40TTAx6YsQPzKE5kx            116432        NaN   NaN  1645197210317
#
#     commit_time user_agent  ... event_id               timestamp category  \
# 0  1.645197e+12    unknown  ...  3469683 2022-02-18 15:13:38.387  SESSION
# 1  1.645197e+12    unknown  ...  3469684 2022-02-18 15:13:40.545  SESSION
# 2           NaN    unknown  ...  3469687 2022-02-18 15:13:43.057  SESSION
# 3  1.645197e+12    unknown  ...  3469676 2022-02-18 15:13:30.415  SESSION
# 4  1.645197e+12    unknown  ...  3469682 2022-02-18 15:13:37.975  SESSION
#
#         action  event_type  session_id  tracking_data  num_participations  \
# 0  REVIEW_TASK        VIEW    111059.0            NaN                   5
# 1         SKIP       CLICK    111059.0            NaN                   5
# 2  REVIEW_TASK        VIEW    111059.0            NaN                   5
# 3  REVIEW_TASK        VIEW    111059.0            NaN                   5
# 4         SKIP       CLICK    111059.0            NaN                   5
#
#    week  num_actions_per_week
# 0    40                     7
# 1    40                     7
# 2    40                     7
# 3    40                     7
# 4    40                     7
#
# [5 rows x 30 columns]

# %%
df.tail()
# Out:
#         transaction_id                     transaction_token   user_id  \
# 948024         1584551  7c9956b4-d2e2-4f30-9245-8155d6636bd5  404604.0
# 948025         1584578  7e328437-52df-4697-94e9-186844c3e269  404604.0
# 948026         1584578  7e328437-52df-4697-94e9-186844c3e269  404604.0
# 948027         1584584  48c02063-8c99-4e2c-b783-b626cf2fcfe9  404604.0
# 948028         1584584  48c02063-8c99-4e2c-b783-b626cf2fcfe9  404604.0
#
#                    document_id  document_version evaluation  \
# 948024  9wGXbOQkPdV6yr6aUa4ubj             89818        NaN
# 948025  a1jzfZLIHDt7LzD8KKha54             39046    PARTIAL
# 948026  a1jzfZLIHDt7LzD8KKha54             39046    PARTIAL
# 948027   AUaU88i0ME6XdsMZWd5gp             39050    PARTIAL
# 948028   AUaU88i0ME6XdsMZWd5gp             39050    PARTIAL
#
#                                                     input     start_time  \
# 948024                                                NaN  1645454941994
# 948025  {"type": "MULTIPLE_CHOICE", "selections": {"3"...  1645455097067
# 948026  {"type": "MULTIPLE_CHOICE", "selections": {"3"...  1645455097067
# 948027  {"type": "MULTIPLE_CHOICE", "selections": {"0"...  1645455137205
# 948028  {"type": "MULTIPLE_CHOICE", "selections": {"0"...  1645455137205
#
#          commit_time user_agent  ... event_id               timestamp  \
# 948024  1.645455e+12    unknown  ...  3509238 2022-02-21 14:49:30.547
# 948025  1.645455e+12    unknown  ...  3509288 2022-02-21 14:51:37.334
# 948026  1.645455e+12    unknown  ...  3509300 2022-02-21 14:52:16.634
# 948027  1.645461e+12    unknown  ...  3509301 2022-02-21 14:52:17.465
# 948028  1.645461e+12    unknown  ...  3510838 2022-02-21 16:33:16.870
#
#        category         action  event_type  session_id  tracking_data  \
# 948024  SESSION           SKIP       CLICK    112060.0            NaN
# 948025  SESSION    REVIEW_TASK        VIEW    112060.0            NaN
# 948026     TASK  SUBMIT_ANSWER       CLICK    112060.0            NaN
# 948027  SESSION    REVIEW_TASK        VIEW    112060.0            NaN
# 948028     TASK  SUBMIT_ANSWER       CLICK    112060.0            NaN
#
#         num_participations  week  num_actions_per_week
# 948024                   4    41                    17
# 948025                   4    41                    17
# 948026                   4    41                    17
# 948027                   4    41                    17
# 948028                   4    41                    17
#
# [5 rows x 30 columns]

# %% [markdown]
# *Definition:* A **significant week** of a particular user is a week in which that user has performed at least $2$ (the closer integer to the lower bound we have defined aboved) significant actions. Note that we have just deleted of our dataframe of the weeks that are not significant.

# %% [markdown]
# Computing the total number of weeks that each user has been actived in the platform:

# %%
test_data = df[['user_id', 'week']].drop_duplicates()
test_data.head()
# Out:
#      user_id  week
# 0   387604.0    40
# 7   387604.0    26
# 50  387604.0    15
# 79  387604.0    16
# 87  387604.0     6

# %%
test_data = pd.DataFrame(test_data.groupby(['user_id']).size()).reset_index()
test_data = test_data.rename(columns = {0 : "num_weeks_per_user"}, errors = "raise")
test_data.head()
# Out:
#     user_id  num_weeks_per_user
# 0  387604.0                   6
# 1  387605.0                  13
# 2  387608.0                   5
# 3  387615.0                   1
# 4  387644.0                   2

# %%
test_data.tail()
# Out:
#        user_id  num_weeks_per_user
# 4916  404583.0                   1
# 4917  404585.0                   1
# 4918  404586.0                   1
# 4919  404592.0                   1
# 4920  404604.0                   1

# %% [markdown]
# Merging `df` with `test_data`:

# %%
df = df.merge(test_data, on = 'user_id')
df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 2         1576012  379dad17-2d6f-42f3-b6f0-68a39664733b  387604.0
# 3         1576009  5094da67-0959-46b4-bb4a-03b5d55259fa  387604.0
# 4         1576009  5094da67-0959-46b4-bb4a-03b5d55259fa  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 2  1taQDeFXg1E9GxbT0YApJU            115407        NaN   NaN  1645197222948
# 3  81qKZ40TTAx6YsQPzKE5kx            116432        NaN   NaN  1645197210317
# 4  81qKZ40TTAx6YsQPzKE5kx            116432        NaN   NaN  1645197210317
#
#     commit_time user_agent  ...               timestamp category       action  \
# 0  1.645197e+12    unknown  ... 2022-02-18 15:13:38.387  SESSION  REVIEW_TASK
# 1  1.645197e+12    unknown  ... 2022-02-18 15:13:40.545  SESSION         SKIP
# 2           NaN    unknown  ... 2022-02-18 15:13:43.057  SESSION  REVIEW_TASK
# 3  1.645197e+12    unknown  ... 2022-02-18 15:13:30.415  SESSION  REVIEW_TASK
# 4  1.645197e+12    unknown  ... 2022-02-18 15:13:37.975  SESSION         SKIP
#
#    event_type  session_id  tracking_data  num_participations  week  \
# 0        VIEW    111059.0            NaN                   5    40
# 1       CLICK    111059.0            NaN                   5    40
# 2        VIEW    111059.0            NaN                   5    40
# 3        VIEW    111059.0            NaN                   5    40
# 4       CLICK    111059.0            NaN                   5    40
#
#    num_actions_per_week  num_weeks_per_user
# 0                     7                   6
# 1                     7                   6
# 2                     7                   6
# 3                     7                   6
# 4                     7                   6
#
# [5 rows x 31 columns]

# %% [markdown]
# Dropping duplicates:

# %%
print("Shape with duplicates:", df.shape)
df = df.drop_duplicates()
print("Shape without duplicates:", df.shape)
# Out:
# Shape with duplicates: (944645, 31)
# Shape without duplicates: (944645, 31)

# %% [markdown]
# Saving intermediate dataframe:

# %%
# Write a pandas dataframe df to gzipped CSV file
df.to_csv("data_3_3.csv.gz", 
           index=False, 
           compression="gzip")

# %% [markdown]
# Histogram of the number of *weeks per user* in the platform:

# %%
num_weeks_per_user = df['num_weeks_per_user'].value_counts(dropna=False)
ax = num_weeks_per_user.plot(
   kind="hist",
   figsize=(8,5),
   title = "Histogram of Number of Weeks per User",
   color=greyscale[1]
)
ax.get_figure().savefig('histogram_number_of_weeks_per_user.jpg')

# %% [markdown]
# Now, I will summarize the data using a boxplot:

# %%
sns.boxplot(x = df['num_weeks_per_user'])
# Out:
# <AxesSubplot:xlabel='num_weeks_per_user'>

# %% [markdown]
# We can appreciate in the boxplot the presence of outliers. However, we don't want to remove users with a high activity in the platform, as they can provide us with useful information in our research.
#
# As we can appreciate in the plot, there are not outliers in the left side of the plot.

# %% [markdown]
# Now, I will apply the Local Outlier Factor method to detect outliers values of the column `num_weeks_per_user`:

# %%
# Import the required library
from sklearn.neighbors import LocalOutlierFactor

# Define LOF class
lof = LocalOutlierFactor(n_neighbors = 2) # consider playing around with 'n_neighbors' parameter

test_data = df[['user_id', 'num_weeks_per_user']]

# Predict whether the numerical columns are outlier or not
y_pred = lof.fit_predict(test_data)

# Select all rows that are not outliers
mask = y_pred != -1
print("Shape with local outliers:", test_data.shape)
test_data_clean = test_data[mask]
test_data_clean.head()
print("Shape without local outliers:", test_data.shape)
# Out:
# Shape with local outliers: (944645, 2)
# Shape without local outliers: (944645, 2)

# %% [markdown]
# It turns out that none of the rows have been deleted using this method.

# %% [markdown]
# Importing intermediate file:

# %%
#df = pd.read_csv('{}/data_3_3.csv.gz'.format(DATA_DIR))

# %% [markdown]
# Deleting rows corresponding to users with less than $2$ significant weeks (since we are interested in doing a time series analysis):

# %%
# Printing the shape of the framework before the cleaning:
print("Shape before cleaning: ", df.shape)

# Cleaning process...
df = df[df['num_weeks_per_user'] > 1]

# Printing the shape of the framework after the cleaning process:
print("Shape after cleaning: ", df.shape)
df.head()
# Out:
# Shape before cleaning:  (944645, 31)
# Shape after cleaning:  (790425, 31)
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 2         1576012  379dad17-2d6f-42f3-b6f0-68a39664733b  387604.0
# 3         1576009  5094da67-0959-46b4-bb4a-03b5d55259fa  387604.0
# 4         1576009  5094da67-0959-46b4-bb4a-03b5d55259fa  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 2  1taQDeFXg1E9GxbT0YApJU            115407        NaN   NaN  1645197222948
# 3  81qKZ40TTAx6YsQPzKE5kx            116432        NaN   NaN  1645197210317
# 4  81qKZ40TTAx6YsQPzKE5kx            116432        NaN   NaN  1645197210317
#
#     commit_time user_agent  ...               timestamp category       action  \
# 0  1.645197e+12    unknown  ... 2022-02-18 15:13:38.387  SESSION  REVIEW_TASK
# 1  1.645197e+12    unknown  ... 2022-02-18 15:13:40.545  SESSION         SKIP
# 2           NaN    unknown  ... 2022-02-18 15:13:43.057  SESSION  REVIEW_TASK
# 3  1.645197e+12    unknown  ... 2022-02-18 15:13:30.415  SESSION  REVIEW_TASK
# 4  1.645197e+12    unknown  ... 2022-02-18 15:13:37.975  SESSION         SKIP
#
#    event_type  session_id  tracking_data  num_participations  week  \
# 0        VIEW    111059.0            NaN                   5    40
# 1       CLICK    111059.0            NaN                   5    40
# 2        VIEW    111059.0            NaN                   5    40
# 3        VIEW    111059.0            NaN                   5    40
# 4       CLICK    111059.0            NaN                   5    40
#
#    num_actions_per_week  num_weeks_per_user
# 0                     7                   6
# 1                     7                   6
# 2                     7                   6
# 3                     7                   6
# 4                     7                   6
#
# [5 rows x 31 columns]

# %%
final_df = df.drop(columns = ['transaction_id', 'transaction_token', 'document_id', 'document_version', 'user_agent', 'validation', 'solution', 'type', 'learn_session_id', 'is_closed', 'type_id', 'is_accepted', 'event_id', 'session_id', 'tracking_data'])

# %% [markdown]
# I have not deleted `start_time` and `commit_time` because it may be interesting to know the amount of time a user has spent performing an action.

# %%
final_df.head()
# Out:
#     user_id evaluation input     start_time   commit_time  topic_id  \
# 0  387604.0        NaN   NaN  1645197218251  1.645197e+12      3250
# 1  387604.0        NaN   NaN  1645197218251  1.645197e+12      3250
# 2  387604.0        NaN   NaN  1645197222948           NaN      3250
# 3  387604.0        NaN   NaN  1645197210317  1.645197e+12      3250
# 4  387604.0        NaN   NaN  1645197210317  1.645197e+12      3250
#
#    max_num_tasks  num_checks               timestamp category       action  \
# 0              5          11 2022-02-18 15:13:38.387  SESSION  REVIEW_TASK
# 1              5          11 2022-02-18 15:13:40.545  SESSION         SKIP
# 2              5          11 2022-02-18 15:13:43.057  SESSION  REVIEW_TASK
# 3              5          11 2022-02-18 15:13:30.415  SESSION  REVIEW_TASK
# 4              5          11 2022-02-18 15:13:37.975  SESSION         SKIP
#
#   event_type  num_participations  week  num_actions_per_week  \
# 0       VIEW                   5    40                     7
# 1      CLICK                   5    40                     7
# 2       VIEW                   5    40                     7
# 3       VIEW                   5    40                     7
# 4      CLICK                   5    40                     7
#
#    num_weeks_per_user
# 0                   6
# 1                   6
# 2                   6
# 3                   6
# 4                   6

# %% [markdown]
# I am dropping `evaluation` and `input` columns because we are not interested in whether a question is correct or not but in the result obtain in the whole level check.

# %%
final_df = df.drop(columns = ['evaluation', 'input', 'event_type'])
final_df = final_df[['user_id', 'timestamp', 'week', 'category', 'action', 'start_time', 'commit_time', 'max_num_tasks', 'num_checks', 'num_participations', 'num_actions_per_week', 'num_weeks_per_user', 'topic_id']]

# %%
final_df = df.drop(columns = ['max_num_tasks'])
final_df.head()
# Out:
#    transaction_id                     transaction_token   user_id  \
# 0         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 1         1576010  a65959df-7bf0-4956-9aa7-511af281fdb5  387604.0
# 2         1576012  379dad17-2d6f-42f3-b6f0-68a39664733b  387604.0
# 3         1576009  5094da67-0959-46b4-bb4a-03b5d55259fa  387604.0
# 4         1576009  5094da67-0959-46b4-bb4a-03b5d55259fa  387604.0
#
#               document_id  document_version evaluation input     start_time  \
# 0  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 1  18FedrGurdA7jklbk0mtVA            115404        NaN   NaN  1645197218251
# 2  1taQDeFXg1E9GxbT0YApJU            115407        NaN   NaN  1645197222948
# 3  81qKZ40TTAx6YsQPzKE5kx            116432        NaN   NaN  1645197210317
# 4  81qKZ40TTAx6YsQPzKE5kx            116432        NaN   NaN  1645197210317
#
#     commit_time user_agent  ...               timestamp category       action  \
# 0  1.645197e+12    unknown  ... 2022-02-18 15:13:38.387  SESSION  REVIEW_TASK
# 1  1.645197e+12    unknown  ... 2022-02-18 15:13:40.545  SESSION         SKIP
# 2           NaN    unknown  ... 2022-02-18 15:13:43.057  SESSION  REVIEW_TASK
# 3  1.645197e+12    unknown  ... 2022-02-18 15:13:30.415  SESSION  REVIEW_TASK
# 4  1.645197e+12    unknown  ... 2022-02-18 15:13:37.975  SESSION         SKIP
#
#    event_type  session_id  tracking_data  num_participations  week  \
# 0        VIEW    111059.0            NaN                   5    40
# 1       CLICK    111059.0            NaN                   5    40
# 2        VIEW    111059.0            NaN                   5    40
# 3        VIEW    111059.0            NaN                   5    40
# 4       CLICK    111059.0            NaN                   5    40
#
#    num_actions_per_week  num_weeks_per_user
# 0                     7                   6
# 1                     7                   6
# 2                     7                   6
# 3                     7                   6
# 4                     7                   6
#
# [5 rows x 30 columns]

# %% [markdown]
# Making sure there are no duplicates lines in the data:

# %%
print("Shape with duplicates:", df.shape)
final_df = final_df.drop_duplicates()
print("Shape without duplicates:", df.shape)
# Out:
# Shape with duplicates: (790425, 31)
# Shape without duplicates: (790425, 31)

# %% [markdown]
# Saving the final version of the data:

# %%
# Write a pandas dataframe df to gzipped CSV file
final_df.to_csv("data.csv.gz", 
           index=False, 
           compression="gzip")
